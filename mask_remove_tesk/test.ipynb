# %%
import io
import os
from PIL import Image

# %%
img = Image.open('test_images/0005.jpg')
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x360 at 0x10818BD10>

# %%
img = Image.open('test_images/0005.jpg')

mask = Image.open('test_results/0005.png').convert("L")
empty = Image.new("RGBA", img.size, 0)
new_img = Image.composite(img, empty, mask)
new_img
# Out:
# <PIL.Image.Image image mode=RGBA size=640x360 at 0x108546350>
